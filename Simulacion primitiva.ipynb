# %% [markdown]
# $Simulación$ $Primitiva$
# $Puntos$ $a)$ $y$ $b)$

# %%
#Declaración de variables
# %pylab inline


#todo en milisegundos-->1000 ms es 1 seg, 60 seg 1 min
kr=1.0/60000.0 # producción de mRNA por minuto
gr=1.0/300000.0 #destrucción de mRNA por minuto (gamma r)
cells=2
time=60*60*1000
#3*60*60*1000 #tiempo de generación en minutos
kp=1.0/1000.0
gp=1.0/180000.0
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# $Código$ $para$ $simulación$

# %%
#proceso

mRNA=zeros((time,cells))
prot=zeros((time,cells))
for j in range(cells):
    for i in range(time):
        a=random.rand(1)[0]
        b=random.rand(1)[0]
        c=random.rand(1)[0]
        d=random.rand(1)[0]
        if(a<kr and b>(gr*mRNA[i-1,j])): #creacion rna
            mRNA[i,j]=mRNA[i-1,j]+1
        elif(a>kr and b<(gr*mRNA[i-1,j])): #destruccion mrna
            mRNA[i,j]=mRNA[i-1,j]-1
        else:
            mRNA[i,j]=mRNA[i-1,j]
        if(c<(kp*mRNA[i-1,j]) and d>(gp*prot[i-1,j])):#creacion prot
            prot[i,j]=prot[i-1,j]+1
        elif(c>(kp*mRNA[i-1,j]) and d<(gp*prot[i-1,j])): #destruccion prot
            prot[i,j]=prot[i-1,j]-1
        else:
            prot[i,j]=prot[i-1,j]
            
plot(range(time),mRNA)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-25d2d2c517a9> in <module>()
#      23
#      24 plot(range(time),mRNA)
# ---> 25 print (time.time()-ini)/60
#      26
#
# AttributeError: 'int' object has no attribute 'time'

# %%
plot(range(time),prot)
# Out:
# [<matplotlib.lines.Line2D at 0x7a79950>,
#  <matplotlib.lines.Line2D at 0x7a79a50>]

# %%
rna_prom=zeros(time)
prot_prom=zeros(time)
rna_std=zeros(time)
prot_std=zeros(time)

for u in range(time):
    rna_prom[u]=mean(mRNA[u,:])
    
for k in range(time):
    prot_prom[k]=mean(prot[k,:])
    
for e in range(time):
    rna_std[e]=std(mRNA[e,:])
    
for w in range(time):
    prot_std[w]=std(prot[w,:])
    
    
plot(range(time),rna_prom)

# %%
plot(range(time),prot_prom)

# %% [markdown]
# $Ruido$ $numérico$ $de$ $RNA$ $y$ $proteínas:$

# %%
noise_rna=mean(rna_prom)/mean(rna_std)
noise_prot=mean(prot_prom)/mean(prot_prom)
print noise_rna,noise_prot
# Out:
# 3.69647483307 1.0

# %% [markdown]
# $Histograma$ $de$ $la$ $distribución$ $en$ $estado$ $estable$

# %%
#hist(mRNA[,:],40)

# %% [markdown]
# $Feedback$ $Negativo$

# %%
#Feedback negativo--> ahora kr/1+(p/k)^2 donde K=1
K=2000
for j in range(cells):
    for i in range(time):    
        a=random.rand(1)[0]
        b=random.rand(1)[0]
        c=random.rand(1)[0]
        d=random.rand(1)[0]
        if(a<(kr/1+(prot[i,j]/K)**2) and b>(gr*mRNA[i-1,j])): #creacion rna
            mRNA[i,j]=mRNA[i-1,j]+1
        elif(a>(kr/1+(prot[i,j]/K)**2) and b<(gr*mRNA[i-1,j])): #destruccion mrna
            mRNA[i,j]=mRNA[i-1,j]-1
        else:
            mRNA[i,j]=mRNA[i-1,j]
        if(c<(kp*mRNA[i-1,j]) and d>(gp*prot[i-1,j])):#creacion prot
            prot[i,j]=prot[i-1,j]+1
        elif(c>(kp*mRNA[i-1,j]) and d<(gp*prot[i-1,j])): #destruccion prot
            prot[i,j]=prot[i-1,j]-1
        else:
            prot[i,j]=prot[i-1,j]
            
plot(range(time),mRNA[:,0])
plot(range)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-c2f515e90e6d> in <module>()
#      21
#      22 plot(range(time),mRNA[:,0])
# ---> 23 plot(range)
#      24
#      25
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    2465         ax.hold(hold)
#    2466     try:
# -> 2467         ret = ax.plot(*args, **kwargs)
#    2468         draw_if_interactive()
#    2469     finally:
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in plot(self, *args, **kwargs)
#    3892
#    3893         for line in self._get_lines(*args, **kwargs):
# -> 3894             self.add_line(line)
#    3895             lines.append(line)
#    3896
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in add_line(self, line)
#    1459             line.set_clip_path(self.patch)
#    1460
# -> 1461         self._update_line_limits(line)
#    1462         if not line.get_label():
#    1463             line.set_label('_line%d'%len(self.lines))
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in _update_line_limits(self, line)
#    1467
#    1468     def _update_line_limits(self, line):
# -> 1469         p = line.get_path()
#    1470         if p.vertices.size > 0:
#    1471             self.dataLim.update_from_path(p, self.ignore_existing_data_limits,
#
# /usr/lib/pymodules/python2.7/matplotlib/lines.pyc in get_path(self)
#     651         """
#     652         if self._invalidy or self._invalidx:
# --> 653             self.recache()
#     654         return self._path
#     655
#
# /usr/lib/pymodules/python2.7/matplotlib/lines.pyc in recache(self, always)
#     399                 y = ma.asarray(yconv, np.float_)
#     400             else:
# --> 401                 y = np.asarray(yconv, np.float_)
#     402             y = y.ravel()
#     403         else:
#
# /usr/lib/python2.7/dist-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     233
#     234     """
# --> 235     return array(a, dtype, copy=False, order=order)
#     236
#     237 def asanyarray(a, dtype=None, order=None):
#
# TypeError: float() argument must be a string or a number
